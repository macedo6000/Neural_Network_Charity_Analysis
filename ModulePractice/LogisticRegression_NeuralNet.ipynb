# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('Resources/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.7161 - accuracy: 0.5833
# Epoch 2/50
# 18/18 [==============================] - 0s 840us/step - loss: 0.6709 - accuracy: 0.6354
# Epoch 3/50
# 18/18 [==============================] - 0s 788us/step - loss: 0.6333 - accuracy: 0.6788
# Epoch 4/50
# 18/18 [==============================] - 0s 873us/step - loss: 0.6027 - accuracy: 0.6927
# Epoch 5/50
# 18/18 [==============================] - 0s 820us/step - loss: 0.5779 - accuracy: 0.7153
# Epoch 6/50
# 18/18 [==============================] - 0s 870us/step - loss: 0.5566 - accuracy: 0.7274
# Epoch 7/50
# 18/18 [==============================] - 0s 890us/step - loss: 0.5400 - accuracy: 0.7309
# Epoch 8/50
# 18/18 [==============================] - 0s 855us/step - loss: 0.5258 - accuracy: 0.7413
# Epoch 9/50
# 18/18 [==============================] - 0s 836us/step - loss: 0.5142 - accuracy: 0.7431
# Epoch 10/50
# 18/18 [==============================] - 0s 884us/step - loss: 0.5046 - accuracy: 0.7500
# Epoch 11/50
# 18/18 [==============================] - 0s 829us/step - loss: 0.4962 - accuracy: 0.7656
# Epoch 12/50
# 18/18 [==============================] - 0s 764us/step - loss: 0.4903 - accuracy: 0.7691
# Epoch 13/50
# 18/18 [==============================] - 0s 855us/step - loss: 0.4836 - accuracy: 0.7726
# Epoch 14/50
# 18/18 [==============================] - 0s 854us/step - loss: 0.4789 - accuracy: 0.7708
# Epoch 15/50
# 18/18 [==============================] - 0s 761us/step - loss: 0.4749 - accuracy: 0.7743
# Epoch 16/50
# 18/18 [==============================] - 0s 804us/step - loss: 0.4710 - accuracy: 0.7778
# Epoch 17/50
# 18/18 [==============================] - 0s 795us/step - loss: 0.4681 - accuracy: 0.7847
# Epoch 18/50
# 18/18 [==============================] - 0s 801us/step - loss: 0.4655 - accuracy: 0.7847
# Epoch 19/50
# 18/18 [==============================] - 0s 824us/step - loss: 0.4631 - accuracy: 0.7812
# Epoch 20/50
# 18/18 [==============================] - 0s 801us/step - loss: 0.4609 - accuracy: 0.7882
# Epoch 21/50
# 18/18 [==============================] - 0s 838us/step - loss: 0.4589 - accuracy: 0.7882
# Epoch 22/50
# 18/18 [==============================] - 0s 826us/step - loss: 0.4568 - accuracy: 0.7865
# Epoch 23/50
# 18/18 [==============================] - 0s 796us/step - loss: 0.4553 - accuracy: 0.7882
# Epoch 24/50
# 18/18 [==============================] - 0s 832us/step - loss: 0.4540 - accuracy: 0.7899
# Epoch 25/50
# 18/18 [==============================] - 0s 821us/step - loss: 0.4525 - accuracy: 0.7899
# Epoch 26/50
# 18/18 [==============================] - 0s 810us/step - loss: 0.4511 - accuracy: 0.7917
# Epoch 27/50
# 18/18 [==============================] - 0s 846us/step - loss: 0.4501 - accuracy: 0.7917
# Epoch 28/50
# 18/18 [==============================] - 0s 805us/step - loss: 0.4487 - accuracy: 0.7917
# Epoch 29/50
# 18/18 [==============================] - 0s 853us/step - loss: 0.4478 - accuracy: 0.7934
# Epoch 30/50
# 18/18 [==============================] - 0s 771us/step - loss: 0.4467 - accuracy: 0.7917
# Epoch 31/50
# 18/18 [==============================] - 0s 854us/step - loss: 0.4458 - accuracy: 0.7899
# Epoch 32/50
# 18/18 [==============================] - 0s 783us/step - loss: 0.4453 - accuracy: 0.7917
# Epoch 33/50
# 18/18 [==============================] - 0s 812us/step - loss: 0.4440 - accuracy: 0.7951
# Epoch 34/50
# 18/18 [==============================] - 0s 809us/step - loss: 0.4432 - accuracy: 0.7951
# Epoch 35/50
# 18/18 [==============================] - 0s 821us/step - loss: 0.4430 - accuracy: 0.7934
# Epoch 36/50
# 18/18 [==============================] - 0s 870us/step - loss: 0.4420 - accuracy: 0.7951
# Epoch 37/50
# 18/18 [==============================] - 0s 842us/step - loss: 0.4409 - accuracy: 0.7951
# Epoch 38/50
# 18/18 [==============================] - 0s 811us/step - loss: 0.4405 - accuracy: 0.7934
# Epoch 39/50
# 18/18 [==============================] - 0s 798us/step - loss: 0.4400 - accuracy: 0.7917
# Epoch 40/50
# 18/18 [==============================] - 0s 855us/step - loss: 0.4393 - accuracy: 0.7969
# Epoch 41/50
# 18/18 [==============================] - 0s 802us/step - loss: 0.4383 - accuracy: 0.7951
# Epoch 42/50
# 18/18 [==============================] - 0s 888us/step - loss: 0.4377 - accuracy: 0.7951
# Epoch 43/50
# 18/18 [==============================] - 0s 923us/step - loss: 0.4368 - accuracy: 0.7951
# Epoch 44/50
# 18/18 [==============================] - 0s 830us/step - loss: 0.4366 - accuracy: 0.7934
# Epoch 45/50
# 18/18 [==============================] - 0s 851us/step - loss: 0.4358 - accuracy: 0.7934
# Epoch 46/50
# 18/18 [==============================] - 0s 827us/step - loss: 0.4349 - accuracy: 0.7951
# Epoch 47/50
# 18/18 [==============================] - 0s 859us/step - loss: 0.4347 - accuracy: 0.8003
# Epoch 48/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4340 - accuracy: 0.7969
# Epoch 49/50
# 18/18 [==============================] - 0s 861us/step - loss: 0.4332 - accuracy: 0.7969
# Epoch 50/50
# 18/18 [==============================] - 0s 827us/step - loss: 0.4332 - accuracy: 0.7969
# 6/6 - 0s - loss: 0.4754 - accuracy: 0.7448 - 93ms/epoch - 16ms/step
# Loss: 0.4753780663013458, Accuracy: 0.7447916865348816
